# %% [markdown]
# <a href="https://colab.research.google.com/github/ThanmayeeGodala-ai/2025-2026-Even--AI-DS-Godala-Thanamyee-4072-/blob/main/28_04_26.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#32 lasso code
from sklearn.linear_model import Lasso
import numpy as np
x=np.array([[1,25,160],[2,30,165],[3,35,170]])
y=np.array([30000,40000,50000])
model=Lasso(alpha=0.1)
model.fit(x,y)
print(model.coef_)
# Out:
# [9.9997300e+03 4.8000000e-02 4.4408921e-18]

# %%
#32 lasso supervised
import numpy as np
from sklearn.linear_model import Lasso
x=np.array([[1,5,2],[2,6,4],[3,7,6],[4,0,8]])
y=np.array([5,10,15,20])
model=Lasso(alpha=0.1)
model.fit(x,y)
print("coefficients:",model.coef_)
# Out:
# coefficients: [ 0.   -0.    2.48]

# %%
#33 similarity and distances
import numpy as np
from scipy.spatial import distance
from scipy.stats import pearsonr
point1=np.array([2,3])
point2=np.array([5,7])
euclidean=distance.euclidean(point1,point1)
manhattan=distance.cityblock(point1,point2)
chebyshev=distance.chebyshev(point1,point2)
hamming=distance.hamming(point1,point2)
cosine_distance=distance.cosine(point1,point2)
cosine_similarity=1-cosine_distance
set1,set2=set(point1),set(point2)
jaccard_similarity=len(set1&set2)/len(set1|set2)
r=pearsonr(point1,point2)
print("euclidean distance:",euclidean)
print("Manhattam distance:",manhattan)
print("chebyshev distance:",chebyshev)
print("cosine distance:",cosine_distance)
print("Jaccard similarity:",jaccard_similarity)
print("pearsonrcorrelation:",r)
print("cosine similarity:",cosine_similarity)
# Out:
# euclidean distance: 0.0
# Manhattam distance: 7
# chebyshev distance: 4
# cosine distance: 0.0005198856603004787
# Jaccard similarity: 0.0
# pearsonrcorrelation: PearsonRResult(statistic=np.float64(1.0), pvalue=np.float64(1.0))
# cosine similarity: 0.9994801143396995

# %%
#34 K-means clustering
import numpy as np
A=np.array([[2,3],[3,4],[4,2]])
B=np.array([[8,7],[9,6],[10,8]])
P=np.array([5,5])
CA=A.mean(axis=0)
CB=B.mean(axis=0)
dA=np.linalg.norm(P-CA)
dB=np.linalg.norm(P-CB)
if dA<dB:
   print("point belongs to cluster A")
else:
   print("point belongs to cluster B")
# Out:
# point belongs to cluster A
