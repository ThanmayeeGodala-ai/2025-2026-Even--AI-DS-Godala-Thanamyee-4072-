# %% [markdown]
# <a href="https://colab.research.google.com/github/ThanmayeeGodala-ai/2025-2026-Even--AI-DS-Godala-Thanamyee-4072-/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=[10,20,30]
print(type(a))
# Out:
# <class 'list'>
