# %% [markdown]
# <a href="https://colab.research.google.com/github/ThanmayeeGodala-ai/2025-2026-Even--AI-DS-Godala-Thanamyee-4072-/blob/main/02_06_2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#35 networkx library & SNA
import networkx as nx
import matplotlib.pyplot as plt
G=nx.Graph()
G.add_edges_from([('A','B'),('A','C'),('B','C'),('C','D')])
plt.figure(figsize=(2,2))
nx.draw(G,with_labels=True)
plt.show()
plt.title("Social Network Analysis")
print("Degree of centrality:",nx.degree_centrality(G))
print("Closeness centrality:",nx.closeness_centrality(G))
print("Betweenness centrality:",nx.betweenness_centrality(G))
# Out:
# Degree of centrality: {'A': 0.6666666666666666, 'B': 0.6666666666666666, 'C': 1.0, 'D': 0.3333333333333333}
# Closeness centrality: {'A': 0.75, 'B': 0.75, 'C': 1.0, 'D': 0.6}
# Betweenness centrality: {'A': 0.0, 'B': 0.0, 'C': 0.6666666666666666, 'D': 0.0}

# %%
#36
import networkx as nx
import matplotlib.pyplot as plt
G=nx.Graph()
G.add_edges_from([('A','B'),('A','C'),('B','D'),('C','D'),('E','F'),('F','H'),('G','H'),('D','E')])
from networkx.algorithms.community import greedy_modularity_communities
communities=greedy_modularity_communities(G)
for i,com in enumerate(communities):
    print(f"community {i+1}:{list(com)}")
nx.draw(G,with_labels=True,node_size=3000)
plt.figure(figsize=(2,1))
plt.show()
# Out:
# community 1:['D', 'B', 'C', 'A']
# community 2:['G', 'E', 'H', 'F']

# %%
#37
import networkx as nx
G=nx.DiGraph()
G.add_edges_from([('A','B'),('A','C'),('B','C'),('C','D'),('E','B'),('E','C')])
pagerank=nx.pagerank(G,alpha=0.85)
print("pagerank:")
for page,rank in pagerank.items():
    print(f"{page}:{rank:.4f}")
# Out:
# pagerank:
# A:0.0894
# B:0.1655
# C:0.3061
# D:0.3496
# E:0.0894
